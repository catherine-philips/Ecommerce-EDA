# %% [markdown]
# # E-Commerce Purchase Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
os.chdir("G:\Data analytics using Python\source")
data=pd.read_csv("commerce_data.txt")
data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data.shape #The dataset has 10000 rows and 14 columns
# Out:
# (10000, 14)

# %% [markdown]
# # Description of the dataset

# %%
data.describe

data.dtypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # Check the dataset for null values

# %%
data.isnull()
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# The dataset does not contain any NAN values.

# %% [markdown]
# # Purchase with the maximum and minimum price

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# # The average purchase

# %%
data['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# # How many people have English 'en' as their Language of choice on the website

# %%
data[data['Language']=="en"]['Language'].count()
# Out:
# 1098

# %% [markdown]
# # How many people have the job title of "Lawyer" ?

# %%
data[data['Job']=='Lawyer']
# Out:
#                                                 Address    Lot AM or PM  \
# 470   9310 Bailey Mountain Apt. 832\r\nLake Jacqueli...  67 tQ       PM
# 508   5064 Nicole Circle\r\nJohnsonburgh, NM 78266-6283  53 rJ       PM
# 1275  4394 Sherry Row Suite 034\r\nSouth Rebecca, MD...  80 jP       PM
# 1569  91733 King Mountains Apt. 356\r\nSouth Tammy, ...  20 Aa       AM
# 1682    5691 Fox Mountains\r\nDudleyside, GU 66765-2101  67 Bk       AM
# 2164  57897 Stacey Pass\r\nLake Jacquelinestad, MA 0...  61 DY       PM
# 2619  720 Laurie Plains Apt. 458\r\nChavezfurt, DE 0...  38 gp       AM
# 2935       816 Cheyenne Causeway\r\nHeidibury, FL 10365  70 nu       AM
# 3663     6218 Mendez Estate\r\nEast Kylemouth, MI 80812  63 BG       PM
# 3738  3921 Courtney River\r\nSouth Donaldmouth, AK 7...  85 Rh       AM
# 3966  3465 Hunter Streets Apt. 976\r\nMedinachester,...  07 xf       PM
# 5053     88431 Thomas Stream\r\nMartinchester, WA 82488  19 fZ       PM
# ...

# %% [markdown]
# # How many people made the purchase during the AM and how many people made the purchase during PM

# %%
data['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# # The most common Job Titles

# %%
data['Job'].value_counts().head(1)
# Out:
# Interior and spatial designer    31
# Name: Job, dtype: int64

# %% [markdown]
# # The least common Job Titles

# %%
data['Job'].value_counts().tail(1)
# Out:
# Information systems manager    5
# Name: Job, dtype: int64

# %% [markdown]
# # Find The Email of the person with the following IP Address: 132.207.160.22

# %%
data[data['IP Address'] == '132.207.160.22']['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# # How many People have American Express as their Credit Card Provider and made a purchase above 50?

# %%
data[data['CC Provider']=='American Express']
# Out:
#                                                 Address    Lot AM or PM  \
# 9     3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
# 17    950 Jacqueline Village Apt. 592\r\nPort Kimber...  23 Rh       PM
# 37         86777 Mary Crescent\r\nCarloshaven, KY 48326  10 LL       AM
# 45    096 Edwards Valleys Suite 917\r\nPerkinsberg, ...  07 Cd       PM
# 51         735 Gaines Plains\r\nRyanfurt, GU 29451-6616  50 Ds       PM
# ...                                                 ...    ...      ...
# 9942         03874 Richard Isle\r\nNew Steven, TX 25541  13 An       PM
# 9944  67427 Mitchell Roads Apt. 905\r\nEast Christin...  13 mI       AM
# 9965  2268 Austin Village Apt. 542\r\nWest Meghan, C...  03 hK       AM
# 9973   92126 Daniel Streets\r\nNorth Patricia, IA 10477  04 QN       PM
# 9998             0096 English Rest\r\nRoystad, IA 12457  74 cL       PM
#
#                                            Browser Info  \
# ...
